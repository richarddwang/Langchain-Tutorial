# %% [markdown]
# 通常文章會 (1)太長塞不進去 LLM (2)資訊太雜導致不能產生一個有效代表的 embedding，因此我們常會需要將 Document 切成一個個的片段。雖然聽起來簡單但其實有很多學問。
#
# 在 Text Splitting 我們會想要達成以下的目標：
# 1. 片段足夠小
# 2. 片段內部高度意義相關
# 3. 高度意義相關的資訊盡量不要被切到不同片段
#
# 而此時我們要考慮的點是
#
# 1. 如何切分文字
# 2. 如何測量片段（Chunk）的大小

# %% [markdown]
# # 1. Recursive Splitting
#
# 這裡介紹一種官方建議，常用且通用的作法
# 1. 將文字切分成很小但高度意義相關的片段單位（通常是句子）
# 2. 將小片段重新接合成大片段直到達到設定的片段大小
# 3. 隨後在與剛做好的大片段重疊一部份的地方，重新開始收集小片段組合成大片段。讓片段之間重疊的目的是避免資訊在片段之間被攔腰斬斷。

# %%
from langchain.document_loaders import NotionDirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_setup import pprint_documents

documents = NotionDirectoryLoader(path='../../data/notion').load()

char_based_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 100, # 每個文件不可超過 100 字元
    chunk_overlap  = 20, # 每個文件從上一個文件的倒數第 20 個字元開始
    length_function = len,
    add_start_index = True,
)

split_documents = char_based_splitter.split_documents(documents=documents)

pprint_documents(split_documents)
# Out:
# Document 1:
#
# 今天來介紹日本最具代表性的軟體開發手法
# 它的名子為 **隕石落下型開發**。
#
# # 第一節
#
# Metadata:{'source': '..\\..\\data\\notion\\隕石落下式開發法.md', 'start_index': 0}
# ----------------------------------------------------------------------------------------------------
# Document 2:
#
# 通常的**瀑布式開發**是像下面這樣的形式:
# | 步驟 | 內容     | 負責人     |
# | ---- | -------- | ---------- |
#
# Metadata:{'source': '..\\..\\data\\notion\\隕石落下式開發法.md', 'start_index': 47}
# ----------------------------------------------------------------------------------------------------
# Document 3:
#
# | 1    | 要件定義 | Producer   |
# | 2    | 基本設計 | Director   |
# | 3    | 詳細設計 | Planner    |
#
# Metadata:{'source': '..\\..\\data\\notion\\隕石落下式開發法.md', 'start_index': 129}
# ----------------------------------------------------------------------------------------------------
# Document 4:
#
# | 4    | 實裝     | Programmer |
#
# Metadata:{'source': '..\\..\\data\\notion\\隕石落下式開發法.md', 'start_index': 216}
# ----------------------------------------------------------------------------------------------------
# Document 5:
#
# 而**隕石式開發**是像下面這樣子的形式：
# |     | 步驟 | 內容     | 負責人     |
# | --- | ---- | -------- | ---------- |
#
# Metadata:{'source': '..\\..\\data\\notion\\隕石落下式開發法.md', 'start_index': 249}
# ----------------------------------------------------------------------------------------------------
# Document 6:
#
# | 神  | 1    | 要件定義 | Producer   |
# | 神  | 2    | 基本設計 | Director   |
#
# Metadata:{'source': '..\\..\\data\\notion\\隕石落下式開發法.md', 'start_index': 342}
# ----------------------------------------------------------------------------------------------------
# Document 7:
#
# | 神  | 3    | 詳細設計 | Planner    |
# | 神  | 4    | 實裝     | Programmer |
#
# Metadata:{'source': '..\\..\\data\\notion\\隕石落下式開發法.md', 'start_index': 410}
# ----------------------------------------------------------------------------------------------------
# Document 8:
#
# 然後就會這樣（全部都被隕石砸到爆炸）：
#
# 💥要件定義💥Producer💥基本設計💥Director💥詳細設計💥Planner💥實裝💥Programmer
#
# 這是敏捷式開法守法的循環
#
# Metadata:{'source': '..\\..\\data\\notion\\隕石落下式開發法.md', 'start_index': 481}
# ----------------------------------------------------------------------------------------------------
# Document 9:
#
# 這是敏捷式開法守法的循環
#
# [要件定義->基本設計->詳細設計->實裝]->[要件定義->基本設計->詳細設計->實裝]->
#
# 但在神的面前都是無力的（全部都被隕石砸到爆炸）
#
# Metadata:{'source': '..\\..\\data\\notion\\隕石落下式開發法.md', 'start_index': 559}
# ----------------------------------------------------------------------------------------------------
# Document 10:
#
# [要件💥定義-💥>基本設計💥->詳細設💥計->實💥裝]<->[要件定💥義->基本設💥計->詳💥細設💥計->💥實裝]->
#
# 在神的一聲令下全部都會**崩壞**，
#
# 而人民會努力地**重建**，
#
# Metadata:{'source': '..\\..\\data\\notion\\隕石落下式開發法.md', 'start_index': 648}
# ----------------------------------------------------------------------------------------------------
# Document 11:
#
# 而人民會努力地**重建**，
#
# 這就是 -- 隕石落下式開發法。
#
# # 第二節
#
# 全部的計畫表都是由**天界**的一己之願來訂定，這被稱為**默示錄**
#
# 雖然在軟體工程中回饋是個重要的因素
#
# Metadata:{'source': '..\\..\\data\\notion\\隕石落下式開發法.md', 'start_index': 729}
# ----------------------------------------------------------------------------------------------------
# Document 12:
#
# 雖然在軟體工程中回饋是個重要的因素
#
# 但回饋**不會傳達**到神的耳裡
#
# 只是我們可以獻上我們的**祈禱**，這些祈禱在**非常稀有**的情況下能上達天聽。
#
# Metadata:{'source': '..\\..\\data\\notion\\隕石落下式開發法.md', 'start_index': 807}
# ----------------------------------------------------------------------------------------------------
# Document 13:
#
# 神會以**各種姿態**出現，有從外部來的，也有從內部來的。
#
# 或者也可能是，還沒遇到的 or 見都見不到的某些人（像是版權持有人、專利所有者，這種形式的神明，則更為凶惡）
#
# Metadata:{'source': '..\\..\\data\\notion\\隕石落下式開發法.md', 'start_index': 887}
# ----------------------------------------------------------------------------------------------------
# Document 14:
#
# 軟體開發的過程中，一步登天這樣有效率的方法是不存在，但相反的，像是天空之城裡一箭毀滅的因陀羅之箭卻是存在的。
#
# # 第三節
#
# 但即使如此，由一個人的神明在建立的秩序**還算好的**。
#
# Metadata:{'source': '..\\..\\data\\notion\\隕石落下式開發法.md', 'start_index': 974}
# ----------------------------------------------------------------------------------------------------
# Document 15:
#
# 問題是，神明有**兩個人以上**的情況。這些神明們偶爾會下達相反的旨意，偶爾會吵架。
#
# 這個我們稱為**諸神黃昏（Ragnarök）**（而受害的永遠都是我們這些人民們）
#
# Metadata:{'source': '..\\..\\data\\notion\\隕石落下式開發法.md', 'start_index': 1067}
# ----------------------------------------------------------------------------------------------------
# Document 16:
#
# 或是，當原本的神明正在建築秩序時，新的神明出現，將舊神一起**全部吹飛**
# 的事情也是有可能發生的。這個我們稱為**聖戰（Jihad）**
#
# Metadata:{'source': '..\\..\\data\\notion\\隕石落下式開發法.md', 'start_index': 1154}
# ----------------------------------------------------------------------------------------------------
# Document 17:
#
# 根據不同的神明，也有擁有絕對的力量但是存在**極微稀薄**的神，而怎麼找也找不到的恐怕是邪神。
#
# Metadata:{'source': '..\\..\\data\\notion\\隕石落下式開發法.md', 'start_index': 1225}
# ----------------------------------------------------------------------------------------------------
# Document 18:
#
# 然後我們千辛萬苦做出的供品，會在我們不知道的地方被**華麗地**發表。然後偶爾會從這邊再誕生出新的需求規格。
#
# # 結論
#
# Metadata:{'source': '..\\..\\data\\notion\\隕石落下式開發法.md', 'start_index': 1274}
# ----------------------------------------------------------------------------------------------------
# Document 19:
#
# # 結論
#
# 今天，我們介紹了日本的軟體開發現場偶爾自然地、應該說災厄地發生的隕石落下式開發法。
#
# **順道一提，對這種情況我們完全無法抵抗。** 你們，應該說我們，只能祈禱能儘早地去適應它。
#
# Metadata:{'source': '..\\..\\data\\notion\\隕石落下式開發法.md', 'start_index': 1330}
# ----------------------------------------------------------------------------------------------------
# Document 20:
#
# 本文章為虛構，跟一切實際的人物、團體無關。（希望是這樣）
#
# Metadata:{'source': '..\\..\\data\\notion\\隕石落下式開發法.md', 'start_index': 1427}

# %% [markdown]
# 但是其實大語言模型 (LLM) 真正的限制輸入長度是以 "token" 為單位而非字元，"token" 是語言模型定義的最小處理單位，可能是一個詞 (word) 或部分的詞 (sub-word)，每個語言模型可能基於不同的辭典 (vocabulary) 且不同辭典不能互通。而 Langchain 也提供了現成的做法讓使用者能改以 "token" 為單位計算長度。

# %%
token_based_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
    model_name="gpt-3.5-turbo-16k", # 使用該模型所使用的辭典 (Vocabulary)
    chunk_size = 100, # 每個文件不可超過 100 toknes
    chunk_overlap  = 20, # 每個文件從上一個文件的倒數第 20 個 token 開始
    add_start_index = True,
)

split_documents = token_based_splitter.split_documents(documents=documents)

pprint_documents(split_documents)
# Out:
# Document 1:
#
# 今天來介紹日本最具代表性的軟體開發手法
# 它的名子為 **隕石落下型開發**。
#
# # 第一節
#
# Metadata:{'source': '..\\..\\data\\notion\\隕石落下式開發法.md', 'start_index': 0}
# ----------------------------------------------------------------------------------------------------
# Document 2:
#
# 通常的**瀑布式開發**是像下面這樣的形式:
# | 步驟 | 內容     | 負責人     |
# | ---- | -------- | ---------- |
# | 1    | 要件定義 | Producer   |
# | 2    | 基本設計 | Director   |
#
# Metadata:{'source': '..\\..\\data\\notion\\隕石落下式開發法.md', 'start_index': 47}
# ----------------------------------------------------------------------------------------------------
# Document 3:
#
# | 2    | 基本設計 | Director   |
# | 3    | 詳細設計 | Planner    |
# | 4    | 實裝     | Programmer |
#
# Metadata:{'source': '..\\..\\data\\notion\\隕石落下式開發法.md', 'start_index': 158}
# ----------------------------------------------------------------------------------------------------
# Document 4:
#
# 而**隕石式開發**是像下面這樣子的形式：
# |     | 步驟 | 內容     | 負責人     |
# | --- | ---- | -------- | ---------- |
# | 神  | 1    | 要件定義 | Producer   |
#
# Metadata:{'source': '..\\..\\data\\notion\\隕石落下式開發法.md', 'start_index': 249}
# ----------------------------------------------------------------------------------------------------
# Document 5:
#
# | 神  | 2    | 基本設計 | Director   |
# | 神  | 3    | 詳細設計 | Planner    |
# | 神  | 4    | 實裝     | Programmer |
#
# Metadata:{'source': '..\\..\\data\\notion\\隕石落下式開發法.md', 'start_index': 376}
# ----------------------------------------------------------------------------------------------------
# Document 6:
#
# 然後就會這樣（全部都被隕石砸到爆炸）：
#
# 💥要件定義💥Producer💥基本設計💥Director💥詳細設計💥Planner💥實裝💥Programmer
#
# 這是敏捷式開法守法的循環
#
# Metadata:{'source': '..\\..\\data\\notion\\隕石落下式開發法.md', 'start_index': 481}
# ----------------------------------------------------------------------------------------------------
# Document 7:
#
# 這是敏捷式開法守法的循環
#
# [要件定義->基本設計->詳細設計->實裝]->[要件定義->基本設計->詳細設計->實裝]->
#
# Metadata:{'source': '..\\..\\data\\notion\\隕石落下式開發法.md', 'start_index': 559}
# ----------------------------------------------------------------------------------------------------
# Document 8:
#
# 但在神的面前都是無力的（全部都被隕石砸到爆炸）
#
# Metadata:{'source': '..\\..\\data\\notion\\隕石落下式開發法.md', 'start_index': 623}
# ----------------------------------------------------------------------------------------------------
# Document 9:
#
# [要件💥定義-💥>基本設計💥->詳細設💥計->實💥裝]<->[要件定💥義->基本設💥計->詳💥細設💥計->💥實裝]->
#
# 在神的一聲令下全部都會**崩壞**，
#
# Metadata:{'source': '..\\..\\data\\notion\\隕石落下式開發法.md', 'start_index': 648}
# ----------------------------------------------------------------------------------------------------
# Document 10:
#
# 而人民會努力地**重建**，
#
# 這就是 -- 隕石落下式開發法。
#
# # 第二節
#
# 全部的計畫表都是由**天界**的一己之願來訂定，這被稱為**默示錄**
#
# Metadata:{'source': '..\\..\\data\\notion\\隕石落下式開發法.md', 'start_index': 729}
# ----------------------------------------------------------------------------------------------------
# Document 11:
#
# 雖然在軟體工程中回饋是個重要的因素
#
# 但回饋**不會傳達**到神的耳裡
#
# 只是我們可以獻上我們的**祈禱**，這些祈禱在**非常稀有**的情況下能上達天聽。
#
# Metadata:{'source': '..\\..\\data\\notion\\隕石落下式開發法.md', 'start_index': 807}
# ----------------------------------------------------------------------------------------------------
# Document 12:
#
# 神會以**各種姿態**出現，有從外部來的，也有從內部來的。
#
# Metadata:{'source': '..\\..\\data\\notion\\隕石落下式開發法.md', 'start_index': 887}
# ----------------------------------------------------------------------------------------------------
# Document 13:
#
# 或者也可能是，還沒遇到的 or 見都見不到的某些人（像是版權持有人、專利所有者，這種形式的神明，則更為凶惡）
#
# Metadata:{'source': '..\\..\\data\\notion\\隕石落下式開發法.md', 'start_index': 918}
# ----------------------------------------------------------------------------------------------------
# Document 14:
#
# 軟體開發的過程中，一步登天這樣有效率的方法是不存在，但相反的，像是天空之城裡一箭毀滅的因陀羅之箭卻是存在的。
#
# # 第三節
#
# Metadata:{'source': '..\\..\\data\\notion\\隕石落下式開發法.md', 'start_index': 974}
# ----------------------------------------------------------------------------------------------------
# Document 15:
#
# # 第三節
#
# 但即使如此，由一個人的神明在建立的秩序**還算好的**。
#
# 問題是，神明有**兩個人以上**的情況。這些神明們偶爾會下達相反的旨意，偶爾會吵架。
#
# Metadata:{'source': '..\\..\\data\\notion\\隕石落下式開發法.md', 'start_index': 1030}
# ----------------------------------------------------------------------------------------------------
# Document 16:
#
# 這個我們稱為**諸神黃昏（Ragnarök）**（而受害的永遠都是我們這些人民們）
#
# Metadata:{'source': '..\\..\\data\\notion\\隕石落下式開發法.md', 'start_index': 1111}
# ----------------------------------------------------------------------------------------------------
# Document 17:
#
# 或是，當原本的神明正在建築秩序時，新的神明出現，將舊神一起**全部吹飛**
# 的事情也是有可能發生的。這個我們稱為**聖戰（Jihad）**
#
# Metadata:{'source': '..\\..\\data\\notion\\隕石落下式開發法.md', 'start_index': 1154}
# ----------------------------------------------------------------------------------------------------
# Document 18:
#
# 根據不同的神明，也有擁有絕對的力量但是存在**極微稀薄**的神，而怎麼找也找不到的恐怕是邪神。
#
# Metadata:{'source': '..\\..\\data\\notion\\隕石落下式開發法.md', 'start_index': 1225}
# ----------------------------------------------------------------------------------------------------
# Document 19:
#
# 然後我們千辛萬苦做出的供品，會在我們不知道的地方被**華麗地**發表。然後偶爾會從這邊再誕生出新的需求規格。
#
# # 結論
#
# Metadata:{'source': '..\\..\\data\\notion\\隕石落下式開發法.md', 'start_index': 1274}
# ----------------------------------------------------------------------------------------------------
# Document 20:
#
# # 結論
#
# 今天，我們介紹了日本的軟體開發現場偶爾自然地、應該說災厄地發生的隕石落下式開發法。
#
# Metadata:{'source': '..\\..\\data\\notion\\隕石落下式開發法.md', 'start_index': 1330}
# ----------------------------------------------------------------------------------------------------
# Document 21:
#
# **順道一提，對這種情況我們完全無法抵抗。** 你們，應該說我們，只能祈禱能儘早地去適應它。
#
# Metadata:{'source': '..\\..\\data\\notion\\隕石落下式開發法.md', 'start_index': 1379}
# ----------------------------------------------------------------------------------------------------
# Document 22:
#
# 本文章為虛構，跟一切實際的人物、團體無關。（希望是這樣）
#
# Metadata:{'source': '..\\..\\data\\notion\\隕石落下式開發法.md', 'start_index': 1427}
